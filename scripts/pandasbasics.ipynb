# %%
name='John'

# %%
print(name)
# Out:
# John

# %%
import pandas as pd
import numpy as np
import string as str
# %matplotlib inline

# %%
print(pd.__version__)
# Out:
# 1.0.1

# %%
arr = [0,2,4,6,8,10]

# %%
s1 = pd.Series(arr)

# %%
s1
# Out:
# 0     0
# 1     2
# 2     4
# 3     6
# 4     8
# 5    10
# dtype: int64

# %%
s1
# Out:
# 0     0
# 1     2
# 2     4
# 3     6
# 4     8
# 5    10
# dtype: int64

# %%
dates = pd.date_range('today', periods=10)
nums = np.random.randn(10,10)
colIdx = list(str.ascii_uppercase[0:10])

df1 = pd.DataFrame(nums, index=dates, columns= colIdx)
df1
# Out:
#                                    A         B         C         D         E  \
# 2020-07-16 22:39:39.699104 -1.337651 -0.889754 -0.739816 -0.798494 -0.376653
# 2020-07-17 22:39:39.699104  0.657119  1.051370  0.497964 -0.437847 -0.235529
# 2020-07-18 22:39:39.699104 -0.563680 -2.930304 -1.685528  0.796076 -0.668148
# 2020-07-19 22:39:39.699104 -1.523551 -0.658744 -0.163728 -1.525031 -0.569902
# 2020-07-20 22:39:39.699104  2.269135  1.266444  0.829246  0.749709  0.929119
# 2020-07-21 22:39:39.699104 -0.740842 -0.551600 -0.048814  0.190516 -0.626804
# 2020-07-22 22:39:39.699104 -0.173319  0.853163  0.905693 -0.669408  0.354240
# 2020-07-23 22:39:39.699104  0.200425 -0.118964  0.728289 -0.503906 -1.071093
# 2020-07-24 22:39:39.699104 -0.752875  0.762765  1.669279 -0.007421  1.402518
# 2020-07-25 22:39:39.699104 -1.153668  0.022537  0.950270  0.016012  1.757290
#
#                                    F         G         H         I         J
# ...

# %%
df1.head(2)
# Out:
#                                    A         B         C         D         E  \
# 2020-07-16 22:38:57.163101  0.956035 -0.057110  0.003146 -0.215540  0.432408
# 2020-07-17 22:38:57.163101  1.906092 -0.050677 -2.069300  1.004084 -0.008668
#
#                                    F         G         H         I         J
# 2020-07-16 22:38:57.163101  0.223580  0.108200 -0.335919 -0.600973  0.250409
# 2020-07-17 22:38:57.163101  0.908759 -0.607865  2.042103  0.016626 -0.843720

# %%
df1.values
# Out:
# array([[-1.59336543e+00,  1.27041520e+00, -3.44349699e-01,
#          8.52425276e-01, -1.17283409e+00,  1.09480204e+00,
#         -5.83749663e-01, -6.37366508e-01, -1.83297246e+00,
#         -7.63852396e-01],
#        [ 5.07298343e-01,  1.70277715e+00, -8.85025924e-02,
#         -2.80072583e-01, -2.47631021e-01, -5.12104460e-01,
#         -2.61039056e-01, -1.64042799e+00,  4.63378715e-01,
#          1.11078767e+00],
#        [ 3.50066302e-02,  1.65687596e+00,  4.01760500e-01,
#         -3.72127394e-01, -1.44144535e+00, -4.42586806e-01,
#         -1.37264735e+00,  1.80239673e-02, -8.72411599e-01,
#         -2.23390425e-01],
#        [ 1.06400571e+00, -7.85630517e-01,  3.27843772e-02,
# 2020-07-20 22:39:39.699104  2.269135  1.266444  0.829246  0.749709  0.929119
# 2020-07-21 22:39:39.699104 -0.740842 -0.551600 -0.048814  0.190516 -0.626804
# 2020-07-22 22:39:39.699104 -0.173319  0.853163  0.905693 -0.669408  0.354240
# 2020-07-23 22:39:39.699104  0.200425 -0.118964  0.728289 -0.503906 -1.071093
# 2020-07-24 22:39:39.699104 -0.752875  0.762765  1.669279 -0.007421  1.402518
# 2020-07-25 22:39:39.699104 -1.153668  0.022537  0.950270  0.016012  1.757290
#
#                                    F         G         H         I         J
# ...

# %%
df2.iloc[0:5]
# Out:
#                                    A         B         C         D         E  \
# 2020-07-16 22:39:39.699104  2.000000 -0.889754 -0.739816 -0.798494 -0.376653
# 2020-07-17 22:39:39.699104  0.657119  1.051370  0.497964 -0.437847 -0.235529
# 2020-07-18 22:39:39.699104  3.000000  3.000000  3.000000  3.000000  3.000000
# 2020-07-19 22:39:39.699104 -1.523551 -0.658744 -0.163728 -1.525031 -0.569902
# 2020-07-20 22:39:39.699104  2.269135  1.266444  0.829246  0.749709  0.929119
#
#                                    F         G         H         I         J
# 2020-07-16 22:39:39.699104  0.233532 -0.231864  0.677588 -2.651770  0.385194
# 2020-07-17 22:39:39.699104  1.238895 -0.750797  0.157461 -0.348763 -0.525403
# 2020-07-18 22:39:39.699104  3.000000  3.000000  3.000000  3.000000  3.000000
# 2020-07-19 22:39:39.699104 -0.256062 -1.071033 -0.683653  0.046317 -2.343581
# 2020-07-20 22:39:39.699104  0.650706  1.103918  0.554063  0.593360 -0.597714

# %%
df2 = df1.copy()
df2.iloc[0,0] = 2.1
df2
# Out:
#                                    A         B         C         D         E  \
# 2020-07-16 22:39:39.699104  2.100000 -0.889754 -0.739816 -0.798494 -0.376653
# 2020-07-17 22:39:39.699104  0.657119  1.051370  0.497964 -0.437847 -0.235529
# 2020-07-18 22:39:39.699104 -0.563680 -2.930304 -1.685528  0.796076 -0.668148
# 2020-07-19 22:39:39.699104 -1.523551 -0.658744 -0.163728 -1.525031 -0.569902
# 2020-07-20 22:39:39.699104  2.269135  1.266444  0.829246  0.749709  0.929119
# 2020-07-21 22:39:39.699104 -0.740842 -0.551600 -0.048814  0.190516 -0.626804
# 2020-07-22 22:39:39.699104 -0.173319  0.853163  0.905693 -0.669408  0.354240
# 2020-07-23 22:39:39.699104  0.200425 -0.118964  0.728289 -0.503906 -1.071093
# 2020-07-24 22:39:39.699104 -0.752875  0.762765  1.669279 -0.007421  1.402518
# 2020-07-25 22:39:39.699104 -1.153668  0.022537  0.950270  0.016012  1.757290
#
#                                    F         G         H         I         J
# ...

# %%
ts = pd.Series(np.random.randn(50), index=pd.date_range('today', periods=50))
ts.plot()

# %%
ts = pd.DataFrame(np.random.randn(50,4), index=pd.date_range('today', periods=50), columns=['A','B','C','D'])
ts.cumsum().plot()
