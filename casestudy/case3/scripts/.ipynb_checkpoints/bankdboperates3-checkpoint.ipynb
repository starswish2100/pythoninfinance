# %%
# !pip install sqlalchemy
# !pip install pymysql

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
db_connection_str = 'mysql+pymysql://root:tianshan@localhost/demo'
db_connection = create_engine(db_connection_str)

# %%
# query = "select * from demo.bankdata"
query = "SELECT `Business Level 2`, `Business Sub Level 3`, `Risk Type`,`Date`,sum(Exposure) as `Exposure Sum`, null as 'Difference in %', null as 'Difference in figure', null as 'Alert' FROM demo.bankdata group by `Business Level 2`, `Business Sub Level 3`, `Risk Type`, `Date` order by `Business Level 2`, `Business Sub Level 3`, `Risk Type`, `Date`;"

df = pd.read_sql(query, con=db_connection)
df
# Out:
#             Business Level 2 Business Sub Level 3            Risk Type  \
# 0   Foreign Exchange & Rates       FX & Rates CVA  Credit Spread Delta
# 1   Foreign Exchange & Rates       FX & Rates CVA  Credit Spread Delta
# 2   Foreign Exchange & Rates       FX & Rates CVA             FX Delta
# 3   Foreign Exchange & Rates       FX & Rates CVA             FX Delta
# 4   Foreign Exchange & Rates       FX & Rates CVA              FX Vega
# 5   Foreign Exchange & Rates       FX & Rates CVA              FX Vega
# 6   Foreign Exchange & Rates       FX & Rates CVA  Interest Rate Delta
# 7   Foreign Exchange & Rates       FX & Rates CVA  Interest Rate Delta
# 8   Foreign Exchange & Rates          FX Business             FX Delta
# 9   Foreign Exchange & Rates          FX Business             FX Delta
# 10  Foreign Exchange & Rates          FX Business  Interest Rate Delta
# 11  Foreign Exchange & Rates          FX Business  Interest Rate Delta
# ...

# %%
# pd.Series(df.iloc[1, 0:3] == df.iloc[2, 0:3]).any()

ref = df.iloc[0, 0:3] 
for index, row in df.iterrows():
    if index > 0:
        if pd.Series(df.iloc[index, 0:3] == df.iloc[index-1, 0:3]).all():
            diff_figure = df.iloc[index, 4] - df.iloc[index-1, 4]
            diff_prec = ((df.iloc[index, 4] - df.iloc[index-1, 4]) / df.iloc[index, 4]) * 100.0
            df.loc[index, 'Difference in %'] = diff_prec
            df.loc[index, 'Difference in figure'] = diff_figure
            
            if df.loc[index, 'Difference in %'] > 10 or df.loc[index, 'Difference in figure'] > 100000:
                df.loc[index, 'Alert'] = 'WARNING'
            
df
# Out:
#             Business Level 2 Business Sub Level 3            Risk Type  \
# 0   Foreign Exchange & Rates       FX & Rates CVA  Credit Spread Delta
# 1   Foreign Exchange & Rates       FX & Rates CVA  Credit Spread Delta
# 2   Foreign Exchange & Rates       FX & Rates CVA             FX Delta
# 3   Foreign Exchange & Rates       FX & Rates CVA             FX Delta
# 4   Foreign Exchange & Rates       FX & Rates CVA              FX Vega
# 5   Foreign Exchange & Rates       FX & Rates CVA              FX Vega
# 6   Foreign Exchange & Rates       FX & Rates CVA  Interest Rate Delta
# 7   Foreign Exchange & Rates       FX & Rates CVA  Interest Rate Delta
# 8   Foreign Exchange & Rates          FX Business             FX Delta
# 9   Foreign Exchange & Rates          FX Business             FX Delta
# 10  Foreign Exchange & Rates          FX Business  Interest Rate Delta
# 11  Foreign Exchange & Rates          FX Business  Interest Rate Delta
# ...

# %%
db_connection.dispose()
