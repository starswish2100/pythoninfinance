# %%
# !pip install sqlalchemy
# !pip install pymysql

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
db_connection_str = 'mysql+pymysql://root:tianshan@localhost/demo'
db_connection = create_engine(db_connection_str)

# %%
# query = "select * from demo.bankdata"
query = "SELECT `Credit Identifier`, `Business Sub Level 3`, `Risk Type`, `Yield Curve`, `Date`, sum(`CVaR`) as 'Sum of CVaR' FROM demo.bankdata WHERE `Business Sub Level 3` = 'Loan Trading' AND `Risk Type` = 'Credit Spread Delta' AND `Yield Curve` = 'Corporate' group by `Credit Identifier`, `Business Sub Level 3`, `Risk Type`, `Yield Curve`, `Date`  order by  `Credit Identifier`, `Business Sub Level 3`, `Risk Type`, `Yield Curve`, `Date` -- select * from bankdata where `Credit Identifier` = 'CORP6' order by `Credit Identifier` desc "
pd.set_option('display.max_rows', df.shape[0]+1)
df = pd.read_sql(query, con=db_connection)
df
# Out:
#    Credit Identifier Business Sub Level 3            Risk Type Yield Curve  \
# 0              CORP1         Loan Trading  Credit Spread Delta   Corporate
# 1              CORP1         Loan Trading  Credit Spread Delta   Corporate
# 2             CORP10         Loan Trading  Credit Spread Delta   Corporate
# 3             CORP10         Loan Trading  Credit Spread Delta   Corporate
# 4             CORP11         Loan Trading  Credit Spread Delta   Corporate
# 5             CORP11         Loan Trading  Credit Spread Delta   Corporate
# 6             CORP12         Loan Trading  Credit Spread Delta   Corporate
# 7             CORP12         Loan Trading  Credit Spread Delta   Corporate
# 8             CORP13         Loan Trading  Credit Spread Delta   Corporate
# 9             CORP13         Loan Trading  Credit Spread Delta   Corporate
# 10            CORP14         Loan Trading  Credit Spread Delta   Corporate
# ...

# %%
# pd.Series(df.iloc[1, 0:3] == df.iloc[2, 0:3]).any()
for index, row in df.iterrows():   
    if index > 0:        
        if pd.Series(df.iloc[index, 0:4] == df.iloc[index-1, 0:4]).all():
            diff = df.iloc[index, 5] - df.iloc[index-1, 5]            
            df.loc[index, 'Diff'] = abs(diff)

df
# Out:
#    Credit Identifier Business Sub Level 3            Risk Type Yield Curve  \
# 0              CORP1         Loan Trading  Credit Spread Delta   Corporate
# 1              CORP1         Loan Trading  Credit Spread Delta   Corporate
# 2             CORP10         Loan Trading  Credit Spread Delta   Corporate
# 3             CORP10         Loan Trading  Credit Spread Delta   Corporate
# 4             CORP11         Loan Trading  Credit Spread Delta   Corporate
# 5             CORP11         Loan Trading  Credit Spread Delta   Corporate
# 6             CORP12         Loan Trading  Credit Spread Delta   Corporate
# 7             CORP12         Loan Trading  Credit Spread Delta   Corporate
# 8             CORP13         Loan Trading  Credit Spread Delta   Corporate
# 9             CORP13         Loan Trading  Credit Spread Delta   Corporate
# 10            CORP14         Loan Trading  Credit Spread Delta   Corporate
# ...

# %%
df.sort_values('Diff', ascending=False)
# Out:
#    Credit Identifier Business Sub Level 3            Risk Type Yield Curve  \
# 26            CORP21         Loan Trading  Credit Spread Delta   Corporate
# 5             CORP11         Loan Trading  Credit Spread Delta   Corporate
# 58             CORP6         Loan Trading  Credit Spread Delta   Corporate
# 28            CORP22         Loan Trading  Credit Spread Delta   Corporate
# 24            CORP20         Loan Trading  Credit Spread Delta   Corporate
# 7             CORP12         Loan Trading  Credit Spread Delta   Corporate
# 22             CORP2         Loan Trading  Credit Spread Delta   Corporate
# 44             CORP3         Loan Trading  Credit Spread Delta   Corporate
# 17            CORP17         Loan Trading  Credit Spread Delta   Corporate
# 20            CORP19         Loan Trading  Credit Spread Delta   Corporate
# 34            CORP25         Loan Trading  Credit Spread Delta   Corporate
# ...

# %%
db_connection.dispose()
